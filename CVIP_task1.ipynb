# %% [markdown]
# """
# Exploratory Data Analysis
#
# 1. Dataset Overview:
#    - The dataset comprises 14,260 entries across 10 columns, representing various attributes related to product sales.
#
# 2. Sales Metrics:
#    - The dataset includes two primary sales metrics: Quantity (QTY) and Value (VALUE), providing insights into the volume and monetary value of products sold.
#    - Minimum quantity recorded is 0 units, indicating instances of no sales, while the maximum quantity is 641 units for a single transaction.
#
# 3. Temporal Distribution:
#    - Sales data is categorized by month (MONTH), with the majority of entries distributed across three months: M1, M2, and M3.
#
# 4. Store Variation:
#    - Sales transactions are recorded across multiple stores (STORECODE), with varying levels of sales activity observed across different store codes.
#
# 5. Product Categorization:
#    - Products are classified into hierarchical categories, including Group Level (GRP), Subgroup Level (SGRP), and Sub-Subgroup Level (SSGRP), providing a structured taxonomy for analysis.
#    - The top-selling product group is "CONFECTIONERY - TOTAL GUM," indicating high demand in this category.
#
# 6. Brand Information:
#    - Each product is associated with company (CMP), mother brand (MBRD), and brand (BRD) attributes, enabling analysis of brand-level performance and market share.
#
# 7. Sales Patterns:
#    - Analysis of sales metrics reveals diverse sales patterns, with a wide range of quantities and values recorded across different product categories and stores.
#    - The top-selling product, "CENTER FRUIT," recorded a maximum quantity of 641 units in a single transaction.
#
# 8. Variability and Trends:
#    - Examination of sales data reveals variability in sales metrics across different temporal periods, stores, and product categories, as well as potential trends or seasonality.
#
# 9. Insights for Decision-Making:
#    - The dataset offers valuable insights for decision-making, including identifying high-performing products, optimizing inventory management, and targeting marketing efforts based on sales patterns and trends.
#
# 10. Opportunities for Improvement:
#     - Analysis of sales data highlights opportunities for improvement, such as identifying underperforming products or product groups for strategic adjustments and enhancing sales strategies to capitalize on emerging trends.
# """

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
url="/content/Hackathon_Ideal_Data.csv.zip"

# %%
df=pd.read_csv(url)

# %%
df.columns
# Out:
# Index(['MONTH', 'STORECODE', 'QTY', 'VALUE', 'GRP', 'SGRP', 'SSGRP', 'CMP',
#        'MBRD', 'BRD'],
#       dtype='object')

# %% [markdown]
# GRP - Group Level
#
#
#
# SGRP - Sub Group Level
#
# SSGRP - Sub Sub Group Level
#
# CMP - Company
#
# MBRD - Mother Brand Level
#
# BRD - Brand Level

# %%
df.head()
# Out:
#   MONTH STORECODE  QTY  VALUE                GRP               SGRP  \
# 0    M1        P1   25     83  HAIR CONDITIONERS  HAIR CONDITIONERS
# 1    M1        P1    6     22  HAIR CONDITIONERS  HAIR CONDITIONERS
# 2    M1        P1    4     15  HAIR CONDITIONERS  HAIR CONDITIONERS
# 3    M1        P1   15     60  HAIR CONDITIONERS  HAIR CONDITIONERS
# 4    M1        P2    0      0  HAIR CONDITIONERS  HAIR CONDITIONERS
#
#                SSGRP                         CMP         MBRD  \
# 0  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 1  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 2  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 3  HAIR CONDITIONERS               L'OREAL INDIA      GARNIER
# 4  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED  CLINIC PLUS
#
#                      BRD
# 0  DOVE HAIR FALL RESCUE
# 1    DOVE INTENSE REPAIR
# 2   DOVE OXYGEN MOISTURE
# 3                FRUCTIS
# 4            CLINIC PLUS

# %%
df.tail()
# Out:
#       MONTH STORECODE  QTY  VALUE                       GRP  \
# 14255    M3       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14256    M3        P8    1     62  SUGAR SUBSTITUTE (11/05)
# 14257    M1        P6    0      0  SUGAR SUBSTITUTE (11/05)
# 14258    M1       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14259    M1        P8    1     62  SUGAR SUBSTITUTE (11/05)
#
#                         SGRP                  SSGRP                 CMP  \
# 14255   POWDER (SUGAR SUBST)   POWDER (SUGAR SUBST)  ZYDUS WELLNESS LTD
# 14256  PELLETS (SUGAR SUBST)  PELLETS (SUGAR SUBST)  ZYDUS WELLNESS LTD
# 14257  PELLETS (SUGAR SUBST)  PELLETS (SUGAR SUBST)  ZYDUS WELLNESS LTD
# 14258   POWDER (SUGAR SUBST)   POWDER (SUGAR SUBST)  ZYDUS WELLNESS LTD
# 14259  PELLETS (SUGAR SUBST)  PELLETS (SUGAR SUBST)  ZYDUS WELLNESS LTD
#
#              MBRD              BRD
# 14255  SUGAR FREE  SUGAR FREE GOLD
# 14256  SUGAR FREE  SUGAR FREE GOLD
# 14257  SUGAR FREE  SUGAR FREE GOLD
# 14258  SUGAR FREE  SUGAR FREE GOLD
# 14259  SUGAR FREE  SUGAR FREE GOLD

# %%
df.sort_values(by=["MONTH"])
# Out:
#      MONTH STORECODE  QTY  VALUE                     GRP               SGRP  \
# 0       M1        P1   25     83       HAIR CONDITIONERS  HAIR CONDITIONERS
# 7106    M1        P3    1      0  AGARBATTI & DHOOPBATTI         DHOOPBATTI
# 7105    M1        P3   16    196  AGARBATTI & DHOOPBATTI          AGARBATTI
# 7104    M1        P3    0      0  AGARBATTI & DHOOPBATTI          AGARBATTI
# 7103    M1        P3    4     36  AGARBATTI & DHOOPBATTI          AGARBATTI
# ...    ...       ...  ...    ...                     ...                ...
# 1758    M3        P7    1      0   SHAMPOO - BY SEGMENTS    BOTTLES / TUBES
# 1759    M3        P7    0      0   SHAMPOO - BY SEGMENTS    BOTTLES / TUBES
# 1760    M3        P7   13    822   SHAMPOO - BY SEGMENTS    BOTTLES / TUBES
# 1750    M3        P6   22     52   SHAMPOO - BY SEGMENTS            SACHETS
# 8934    M3        P6    1     44         KETCHUPS/SAUCES    KETCHUPS/SAUCES
#
#                   SSGRP                         CMP         MBRD  \
# 0     HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 7106         DHOOPBATTI          N RANGA RAO & SONS         VASU
# 7105          AGARBATTI              PARIMAL MANDIR      PARIMAL
# 7104          AGARBATTI          N RANGA RAO & SONS        CYCLE
# 7103          AGARBATTI          N RANGA RAO & SONS        CYCLE
# ...                 ...                         ...          ...
# 1758    BOTTLES / TUBES               EMAMI LIMITED    KESH KING
# 1759    BOTTLES / TUBES               HIMALAYA DRUG     HIMALAYA
# 1760    BOTTLES / TUBES  HINDUSTAN UNILEVER LIMITED  CLINIC PLUS
# 1750            SACHETS  HINDUSTAN UNILEVER LIMITED         DOVE
# 8934    KETCHUPS/SAUCES         MAPRO FOODS PVT LTD        MAPRO
#
#                          BRD
# 0      DOVE HAIR FALL RESCUE
# 7106                    VASU
# 7105                 PARIMAL
# 7104          CYCLE HERITAGE
# 7103    CYCLE GOOD LUCK ROSE
# ...                      ...
# 1758               KESH KING
# 1759  HIMALAYA ANTI DANDRUFF
# 1760             CLINIC PLUS
# 1750   DOVE HAIR FALL RESCUE
# 8934                   MAPRO
#
# [14260 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14260 entries, 0 to 14259
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      14260 non-null  object
#  1   STORECODE  14260 non-null  object
#  2   QTY        14260 non-null  int64
#  3   VALUE      14260 non-null  int64
#  4   GRP        14260 non-null  object
#  5   SGRP       14260 non-null  object
#  6   SSGRP      14260 non-null  object
#  7   CMP        14260 non-null  object
#  8   MBRD       14260 non-null  object
#  9   BRD        14260 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# MONTH        0
# STORECODE    0
# QTY          0
# VALUE        0
# GRP          0
# SGRP         0
# SSGRP        0
# CMP          0
# MBRD         0
# BRD          0
# dtype: int64

# %%
df.shape
# Out:
# (14260, 10)

# %%
df.describe()
# Out:
#                 QTY         VALUE
# count  14260.000000  14260.000000
# mean      16.354488    294.455330
# std       34.365583    760.129558
# min        0.000000      0.000000
# 25%        1.000000     10.000000
# 50%        4.000000     99.000000
# 75%       16.000000    283.000000
# max      641.000000  24185.000000

# %%
df["MONTH"].unique()
# Out:
# array(['M1', 'M3', 'M2'], dtype=object)

# %%
df["MONTH"].value_counts()
# Out:
# M2    4816
# M1    4804
# M3    4640
# Name: MONTH, dtype: int64

# %%
df["STORECODE"].unique()
# Out:
# array(['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10'],
#       dtype=object)

# %%
df["STORECODE"].value_counts().sort_values(ascending=False)
# Out:
# P8     2642
# P6     2097
# P10    1508
# P2     1471
# P4     1454
# P3     1362
# P9     1188
# P1     1061
# P7      850
# P5      627
# Name: STORECODE, dtype: int64

# %%
df[["GRP","SGRP","SSGRP","CMP","MBRD","BRD"]].nunique().sort_values(ascending=False)
# Out:
# BRD      1613
# MBRD      818
# CMP       512
# SSGRP     242
# SGRP      177
# GRP        80
# dtype: int64

# %%
sns.barplot(data = df,x="MONTH",y="VALUE")
# Out:
# <Axes: xlabel='MONTH', ylabel='VALUE'>

# %%
qty_storecode = df.groupby("STORECODE")["QTY"].sum().sort_values(ascending=False)
qty_storecode
# Out:
# STORECODE
# P4     34089
# P8     32003
# P3     27602
# P5     25993
# P10    21323
# P6     21178
# P7     21114
# P9     20904
# P1     18526
# P2     10483
# Name: QTY, dtype: int64

# %%
sns.barplot(data=qty_storecode)
# Out:
# <Axes: xlabel='STORECODE', ylabel='QTY'>

# %%
value_storecode= df.groupby("STORECODE")["VALUE"].sum().sort_values(ascending=False)
value_storecode
# Out:
# STORECODE
# P8     671988
# P7     571136
# P6     502627
# P4     471566
# P3     428550
# P5     335086
# P1     334710
# P9     313426
# P10    285820
# P2     284024
# Name: VALUE, dtype: int64

# %%
sns.barplot(data=value_storecode)
# Out:
# <Axes: xlabel='STORECODE', ylabel='VALUE'>

# %%
sns.barplot(data=df,x="STORECODE",y="VALUE",hue="MONTH")
plt.title("VALUES by Store and Month")
# Out:
# Text(0.5, 1.0, 'VALUES by Store and Month')

# %%
sns.barplot(data=df,x="STORECODE",y="QTY",hue="MONTH")
plt.title("Quantity by Store and Month")
plt.xlabel("Store Code")
plt.ylabel("Quantity")
# Out:
# Text(0, 0.5, 'Quantity')

# %%
#top ten
qty_sort = df.sort_values(by="QTY",ascending=False).head(10)

# %%
qty_sort
# Out:
#       MONTH STORECODE  QTY  VALUE                         GRP            SGRP  \
# 9602     M1       P10  641    641   CONFECTIONERY - TOTAL GUM     BUBBLE GUMS
# 4595     M3        P9  625   5126                PACKAGED TEA      MAIN PACKS
# 4779     M3        P6  605    775                      COFFEE  INSTANT COFFEE
# 12861    M1        P1  554   2009  BISCUITS - CORE & NON CORE         GLUCOSE
# 4750     M2        P6  541    990                      COFFEE  INSTANT COFFEE
# 1836     M3        P9  435    435       SHAMPOO - BY SEGMENTS         SACHETS
# 1579     M1        P7  422    422       SHAMPOO - BY SEGMENTS         SACHETS
# 7557     M2        P7  416   5383            ALL IODISED SALT   POWDERED SALT
# 1383     M2        P7  408    408       SHAMPOO - BY SEGMENTS         SACHETS
# 4702     M1        P9  407   4935                PACKAGED TEA      MAIN PACKS
#
#                 SSGRP                         CMP          MBRD           BRD
# 9602      BUBBLE GUMS          PERFETTI VAN MELLE  CENTER FRUIT  CENTER FRUIT
# 4595       MAIN PACKS             HASMUKHRAI & CO       SOCIETY  SOCIETY LEAF
# 4779   INSTANT COFFEE  HINDUSTAN UNILEVER LIMITED           BRU   BRU INSTANT
# 12861         GLUCOSE                 PARLE PRODS       PARLE-G       PARLE-G
# 4750   INSTANT COFFEE  HINDUSTAN UNILEVER LIMITED           BRU   BRU INSTANT
# 1836          SACHETS  HINDUSTAN UNILEVER LIMITED   CLINIC PLUS   CLINIC PLUS
# 1579          SACHETS  HINDUSTAN UNILEVER LIMITED   CLINIC PLUS   CLINIC PLUS
# 7557    POWDERED SALT        DIVYA SALT PVT. LTD.     CAPS COOK     CAPS COOK
# 1383          SACHETS  HINDUSTAN UNILEVER LIMITED   CLINIC PLUS   CLINIC PLUS
# 4702       MAIN PACKS             HASMUKHRAI & CO       SOCIETY  SOCIETY LEAF

# %%
qty_sort

# %%
px.bar(qty_sort,x="MBRD",y="QTY",color="MONTH")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c9dc940b-0879-495f-940f-c97e36249104" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9dc940b-0879-495f-940f-c97e36249104")) {                    Plotly.newPlot(                        "c9dc940b-0879-495f-940f-c97e36249104",                        [{"alignmentgroup":"True","hovertemplate":"MONTH=M1\u003cbr\u003eMBRD=%{x}\u003cbr\u003eQTY=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"M1","offsetgroup":"M1","orientation":"v","showlegend":true,"textposition":"auto","x":["CENTER FRUIT","PARLE-G","CLINIC PLUS","SOCIETY"],"xaxis":"x","y":[641,554,422,407],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"MONTH=M3\u003cbr\u003eMBRD=%{x}\u003cbr\u003eQTY=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M3","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M3","offsetgroup":"M3","orientation":"v","showlegend":true,"textposition":"auto","x":["SOCIETY","BRU","CLINIC PLUS"],"xaxis":"x","y":[625,605,435],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"MONTH=M2\u003cbr\u003eMBRD=%{x}\u003cbr\u003eQTY=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M2","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"M2","offsetgroup":"M2","orientation":"v","showlegend":true,"textposition":"auto","x":["BRU","CAPS COOK","CLINIC PLUS"],"xaxis":"x","y":[541,416,408],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33 ...

# %%
px.bar(df,x="MONTH",y="VALUE",hover_data={"STORECODE":True,"QTY":True,"GRP":True,"CMP":True,"MBRD":True,"BRD":True},title="BAR CHART WITH HOVER INFORMATION",)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="60fb1188-f78b-4dda-bc3c-6e596007cfd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60fb1188-f78b-4dda-bc3c-6e596007cfd6")) {                    Plotly.newPlot(                        "60fb1188-f78b-4dda-bc3c-6e596007cfd6",                        [{"alignmentgroup":"True","customdata":[["P1",25,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE HAIR FALL RESCUE"],["P1",6,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE INTENSE REPAIR"],["P1",4,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE OXYGEN MOISTURE"],["P1",15,"HAIR CONDITIONERS","L'OREAL INDIA","GARNIER","FRUCTIS"],["P2",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","CLINIC PLUS","CLINIC PLUS"],["P2",1,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE DAILY SHINE"],["P2",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE ENVIRONMENTAL DEFENCE"],["P2",10,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE HAIR FALL RESCUE"],["P2",11,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE INTENSE REPAIR"],["P2",2,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE OXYGEN MOISTURE"],["P2",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","SUNSILK","SUNSILK SHINY SMOOTH & TNGL FR"],["P2",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","SUNSILK","SUNSILK STUNNING BLACK SHINE"],["P2",4,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","SUNSILK","SUNSILK THICK & LONG"],["P2",0,"HAIR CONDITIONERS","PROCTER & GAMBLE","PANTENE","PANTENE CONDITIONER"],["P3",29,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE DAILY SHINE"],["P3",2,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE INTENSE REPAIR"],["P3",2,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE OXYGEN MOISTURE"],["P3",20,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","TRESEMME","TRESEMME HAIR FALL DEFENSE"],["P3",34,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","TRESEMME","TRESEMME SMOOTH & SHINE"],["P3",15,"HAIR CONDITIONERS","PROCTER & GAMBLE","PANTENE","PANTENE CONDITIONER"],["P4",15,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE INTENSE REPAIR"],["P4",13,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","TRESEMME","TRESEMME KERATIN SMOOTH"],["P4",8,"HAIR CONDITIONERS","PROCTER & GAMBLE","PANTENE","PANTENE CONDITIONER"],["P5",22,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE DAILY SHINE"],["P5",42,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE HAIR FALL RESCUE"],["P5",42,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE INTENSE REPAIR"],["P5",39,"HAIR CONDITIONERS","PROCTER & GAMBLE","PANTENE","PANTENE CONDITIONER"],["P6",4,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE DAILY SHINE"],["P6",4,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE HAIR FALL RESCUE"],["P6",4,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE INTENSE REPAIR"],["P6",4,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE OXYGEN MOISTURE"],["P7",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","TRESEMME","TRESEMME SMOOTH & SHINE"],["P8",22,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE DAILY SHINE"],["P8",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE DRYNESS CARE"],["P8",44,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE HAIR FALL RESCUE"],["P8",28,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE INTENSE REPAIR"],["P8",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","DOVE","DOVE OXYGEN MOISTURE"],["P8",0,"HAIR CONDITIONERS","HINDUSTAN UNILEVER LIMITED","SUNSILK","SUNSILK LONG & HEALTHY GROWTH"],["P8",0,"HAIR CONDITIONERS","HINDUSTAN UNI ...

# %%
fig=px.treemap(df,path=["MONTH","STORECODE","GRP","SGRP"],values="VALUE")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d315d033-4529-4048-8d60-25da71ca87da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d315d033-4529-4048-8d60-25da71ca87da")) {                    Plotly.newPlot(                        "d315d033-4529-4048-8d60-25da71ca87da",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eVALUE=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["M1\u002fP1\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP1\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP1\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP2\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP2\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP2\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP3\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP3\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP3\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP4\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP4\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP4\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP6\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP6\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP6\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP7\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP7\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP7\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP8\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP8\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP8\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP6\u002fSHAVING PREPARATIONS\u002fAEROSOLS","M2\u002fP6\u002fSHAVING PREPARATIONS\u002fAEROSOLS","M3\u002fP6\u002fSHAVING PREPARATIONS\u002fAEROSOLS","M1\u002fP6\u002fAFTER SHAVE LOTIONS\u002fAFTER SHAVE LOTIONS","M2\u002fP6\u002fAFTER SHAVE LOTIONS\u002fAFTER SHAVE LOTIONS","M3\u002fP6\u002fAFTER SHAVE LOTIONS\u002fAFTER SHAVE LOTIONS","M1\u002fP1\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP1\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP1\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP10\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP10\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP10\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP2\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP2\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP2\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP3\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP3\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP3\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP4\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP4\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP4\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP5\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP5\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP5\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP6\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP6\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP6\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP7\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP7\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP7\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP8\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP8\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP8\u002fAG ...

# %%
fig=px.sunburst(df,path=["MONTH","STORECODE","GRP","SGRP"],values="VALUE")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d40d6692-583d-4860-8a45-669ec6df0be6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d40d6692-583d-4860-8a45-669ec6df0be6")) {                    Plotly.newPlot(                        "d40d6692-583d-4860-8a45-669ec6df0be6",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eVALUE=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["M1\u002fP1\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP1\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP1\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP2\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP2\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP2\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP3\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP3\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP3\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP4\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP4\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP4\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP6\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP6\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP6\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP7\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP7\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP7\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP8\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M2\u002fP8\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M3\u002fP8\u002fHOME INSECTICIDES CTG  (8\u002f93)\u002fAEROSOL","M1\u002fP6\u002fSHAVING PREPARATIONS\u002fAEROSOLS","M2\u002fP6\u002fSHAVING PREPARATIONS\u002fAEROSOLS","M3\u002fP6\u002fSHAVING PREPARATIONS\u002fAEROSOLS","M1\u002fP6\u002fAFTER SHAVE LOTIONS\u002fAFTER SHAVE LOTIONS","M2\u002fP6\u002fAFTER SHAVE LOTIONS\u002fAFTER SHAVE LOTIONS","M3\u002fP6\u002fAFTER SHAVE LOTIONS\u002fAFTER SHAVE LOTIONS","M1\u002fP1\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP1\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP1\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP10\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP10\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP10\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP2\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP2\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP2\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP3\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP3\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP3\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP4\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP4\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP4\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP5\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP5\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP5\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP6\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP6\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP6\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP7\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP7\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP7\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M1\u002fP8\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M2\u002fP8\u002fAGARBATTI & DHOOPBATTI\u002fAGARBATTI","M3\u002fP8\u002fAG ...
